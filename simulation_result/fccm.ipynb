# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# Load data
scaling_quant_result = pd.read_csv('quantization_inout_en_de3.csv')

# Set up the figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))  # Increase figure size for better clarity

# Font size for labels and ticks
label_font_size = 16
tick_font_size = 16

# First subplot: OPUS-MT-EN-DE plot
ax1 = axes[0]
baseline_bleu = 41.337328250540224

# Draw baseline and compression ratio reference lines
ax1.axhline(baseline_bleu, color='red', linestyle='--', linewidth=1, alpha=0.8, label='FP32 Baseline')

# Set labels with increased font size
ax1.set_title('OPUS-MT-EN-DE', fontsize=label_font_size)
ax1.set_xlabel('Weight Word Length', fontsize=label_font_size)
ax1.set_ylabel('BLEU Score', fontsize=label_font_size)

# Set tick font size
ax1.tick_params(axis='both', which='major', labelsize=tick_font_size)

act_wls = [16, 8, 6]
# Use Viridis colormap
viridis = cm.get_cmap('viridis', len(act_wls))  # Get distinct colors from Viridis

for i, act_wl in enumerate(act_wls):
    # Plot BLEU scores for different scaling methods with rounded dots
    ax1.plot(
        scaling_quant_result[
            (scaling_quant_result["Weight Word Length"] != 2) &
            (scaling_quant_result["Activation Word Length"] == act_wl)
        ]["Weight Word Length"],
        scaling_quant_result[
            (scaling_quant_result["Weight Word Length"] != 2) &
            (scaling_quant_result["Activation Word Length"] == act_wl)
        ]["BLEU Score (Range-Based)"],
        linewidth=2,
        alpha=0.8,
        label=f'Activation Word Length {act_wl}',
        color=viridis(i), marker='D', linestyle='-'  # Round dots for data points
    )

# Add legend with increased font size
ax1.legend(fontsize=14)
ax1.grid(linestyle='--', alpha=0.7)

# Second subplot: OPUS-MT-FR-EN plot
ax2 = axes[1]

baseline_bleu = 31.295117829679363

# Draw baseline and compression ratio reference lines
ax2.axhline(baseline_bleu, color='red', linestyle='--', linewidth=1, alpha=0.8, label='FP32 Baseline')
scaling_quant_result = pd.read_csv('quantization_inout_fr_en3.csv')

# Set labels with increased font size
ax2.set_title('OPUS-MT-FR-EN', fontsize=14)
ax2.set_xlabel('Weight Word Length', fontsize=label_font_size)
ax2.set_ylabel('BLEU Score', fontsize=label_font_size)

# Set tick font size
ax2.tick_params(axis='both', which='major', labelsize=tick_font_size)

for i, act_wl in enumerate(act_wls):
    # Plot BLEU scores for different scaling methods with rounded dots
    ax2.plot(
        scaling_quant_result[
            (scaling_quant_result["Weight Word Length"] != 2) &
            (scaling_quant_result["Activation Word Length"] == act_wl)
        ]["Weight Word Length"],
        scaling_quant_result[
            (scaling_quant_result["Weight Word Length"] != 2) &
            (scaling_quant_result["Activation Word Length"] == act_wl)
        ]["BLEU Score (Range-Based)"],
        linewidth=2,
        alpha=0.8,
        label=f'Activation Word Length {act_wl}',
        color=viridis(i), marker='D', linestyle='-'  # Round dots for data points
    )

# Add legend with increased font size
ax2.legend(fontsize=14)
ax2.grid(linestyle='--', alpha=0.7)

# Adjust layout and show the plot
plt.tight_layout()

# Save the figure to a file
plt.savefig('/Users/justin/Desktop/FCCM/section1/quantisation.png', dpi=500, bbox_inches='tight')  # Save as a PNG file

plt.show()
# Out:
# /var/folders/6l/tkj8jq4d2c1fvr2j6g1kj0n40000gn/T/ipykernel_32639/316726058.py:32: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   viridis = cm.get_cmap('viridis', len(act_wls))  # Get distinct colors from Viridis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# Load data
scaling_quant_result = pd.read_csv('quantization_inout_en_de3.csv')

# Set up the figure with a single plot of size (7, 5)
fig, ax1 = plt.subplots(figsize=(7, 5))  # Single plot with the new size

# Font size for labels and ticks
label_font_size = 16
tick_font_size = 16

# First subplot: OPUS-MT-EN-DE plot
baseline_bleu = 41.337328250540224

# Draw baseline and compression ratio reference lines
ax1.axhline(baseline_bleu, color='red', linestyle='--', linewidth=1, alpha=0.8, label='FP32 Baseline')

# Set labels with increased font size
ax1.set_title('OPUS-MT-EN-DE', fontsize=label_font_size)
ax1.set_xlabel('Weight Word Length', fontsize=label_font_size)
ax1.set_ylabel('BLEU Score', fontsize=label_font_size)

# Set tick font size
ax1.tick_params(axis='both', which='major', labelsize=tick_font_size)

act_wls = [16, 8, 6]
# Use Viridis colormap
viridis = cm.get_cmap('viridis', len(act_wls)+2)  # Get distinct colors from Viridis

for i, act_wl in enumerate(act_wls):
    # Plot BLEU scores for different scaling methods with rounded dots
    ax1.plot(
        scaling_quant_result[
            (scaling_quant_result["Weight Word Length"] != 2) &
            (scaling_quant_result["Activation Word Length"] == act_wl)
        ]["Weight Word Length"],
        scaling_quant_result[
            (scaling_quant_result["Weight Word Length"] != 2) &
            (scaling_quant_result["Activation Word Length"] == act_wl)
        ]["BLEU Score (Range-Based)"],
        linewidth=2,
        alpha=0.8,
        label=f'Activation Word Length {act_wl}',
        color=viridis(i), marker='D', linestyle='-'  # Round dots for data points
    )

# Add legend with increased font size
ax1.legend(fontsize=14)
ax1.grid(linestyle='--', alpha=0.7)

# Show plot
plt.tight_layout()

# Save the figure to a file
plt.savefig('/Users/justin/Desktop/FCCM/section1/quantisation.png', dpi=500, bbox_inches='tight')  # Save as a PNG file

plt.show()
# Out:
# /var/folders/6l/tkj8jq4d2c1fvr2j6g1kj0n40000gn/T/ipykernel_35725/3594250582.py:31: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   viridis = cm.get_cmap('viridis', len(act_wls)+2)  # Get distinct colors from Viridis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# Load data
scaling_quant_result = pd.read_csv('quantization_inout_en_de3.csv')

# Set up the plot
plt.figure(figsize=(7, 5))
baseline_bleu = 41.337328250540224

# Font size for labels and ticks
label_font_size = 12
tick_font_size = 12

# Draw baseline and compression ratio reference lines
plt.axhline(baseline_bleu, color='red', linestyle='--', linewidth=2, alpha=0.5, label='FP32 Baseline')
plt.axvline(1, color='gray', linestyle=':', linewidth=4, alpha=0.5)

# Set labels
plt.title('BLEU Score vs Compression Ratio (Activation Word Length 8)', fontsize=label_font_size)
plt.xlabel('Compression Ratio', fontsize=label_font_size)
plt.ylabel('BLEU Score', fontsize=label_font_size)

# Set tick font size
plt.tick_params(axis='both', which='major', labelsize=tick_font_size)

# Use Viridis colormap
viridis = cm.get_cmap('viridis', 4)  # Get 4 distinct colors from Viridis

act_wl = 8

# Plot BLEU scores for different scaling methods with rounded dots
plt.plot(
    scaling_quant_result[(scaling_quant_result["Activation Word Length"] == act_wl)]["Compression Ratio"],
    scaling_quant_result[(scaling_quant_result["Activation Word Length"] == act_wl)]["BLEU Score (Range-Based)"],
    linewidth=2,
    alpha=0.5,
    label='Quantisation Baseline',
    color='red', linestyle='-'  # Round dots for data points
)


# Load the SVD data
svd_data1 = pd.read_csv('svd_quant_inout_en_de_3.csv')
# svd_data1 = pd.concat([svd_data1, pd.read_csv('svd_quant_inout_en_de_4.csv')], ignore_index=True)
# svd_data1 = pd.concat([svd_data1, pd.read_csv('svd_quant_inout_en_de_5.csv')], ignore_index=True)
# svd_data1 = pd.concat([svd_data1, pd.read_csv('svd_quant_inout_en_de_6.csv')], ignore_index=True)
# svd_data1 = pd.concat([svd_data1, pd.read_csv('svd_quant_inout_en_de_7.csv')], ignore_index=True)
# svd_data1 = pd.concat([svd_data1, pd.read_csv('svd_quant_inout_en_de_8.csv')], ignore_index=True)
svd_data2 = svd_data1


# Define the word lengths to plot for the SVD data
svd_word_lengths = [3]
svd_word_lengths1 = [3]

# Generate a colormap with Viridis for the SVD plots
svd_viridis = cm.get_cmap('viridis', len(svd_word_lengths))

# Create a scatter plot for each word length in the SVD data
for idx, (wl1, wl2) in enumerate(zip(svd_word_lengths,svd_word_lengths1)):
    # Filter the data for the current word length
    
    svd_data1_wl = svd_data1[(svd_data1['Activation Word Length'] == act_wl) & (svd_data1['Weight Word Length'] == wl1)]
    svd_data1_wl1 = svd_data2[(svd_data2['Activation Word Length'] == act_wl) & (svd_data2['Weight Word Length'] == wl2)]

    # Scatter plot for the current word length
    plt.scatter(
        svd_data1_wl['Compression Ratio'],
        svd_data1_wl["Quant SVD BLEU (Range-Based)"],
        s=170,
        marker='o',
        alpha=0.2,
        color=svd_viridis(idx / len(svd_word_lengths)),
        label=f'Quant SVD\nWord Length {wl1}'
    )

    # Scatter plot for the current word length
    plt.scatter(
        svd_data1_wl1['Compression Ratio'],
        svd_data1_wl1["Iterative Quant SVD BLEU (Range-Based)"],
        s=100,
        marker='o',
        alpha=1,
        color=svd_viridis(idx / len(svd_word_lengths)),
        label=f'Iterative Quant SVD\nWord Length {wl2}'
    )

optimal = pd.read_csv('svd_quant_inout_en_de_3.csv')
plt.scatter(
    optimal['Compression Ratio'],
    svd_data1_wl1["Iterative Quant SVD BLEU (Range-Based)"],
    s=100,
    marker='o',
    alpha=1,
    color=svd_viridis(idx / len(svd_word_lengths)),
    label=f'Iterative Quant SVD\nWord Length {wl2}'
)


# Add legend outside the plot
plt.legend(loc='lower left',fontsize=12)  # Legend outside plotting area
plt.grid(linestyle='--', alpha=0.7)
plt.xlim([4,15])
plt.ylim([25,43])

# Adjust layout and show the plot
plt.tight_layout(rect=[0, 0, 1, 1])  # Leave space for legend

# Save the figure to a file
plt.savefig('/Users/justin/Desktop/FCCM/section6/svd_quant.png', dpi=500, bbox_inches='tight')  # Save as a PNG file

plt.show()
# Out:
# /var/folders/6l/tkj8jq4d2c1fvr2j6g1kj0n40000gn/T/ipykernel_35725/2173316704.py:29: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   viridis = cm.get_cmap('viridis', 4)  # Get 4 distinct colors from Viridis
# /var/folders/6l/tkj8jq4d2c1fvr2j6g1kj0n40000gn/T/ipykernel_35725/2173316704.py:59: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   svd_viridis = cm.get_cmap('viridis', len(svd_word_lengths))
