# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
from matplotlib.cm import get_cmap

# Load data
scaling_quant_result = pd.read_csv('quantization_inout_en_de3.csv')

# Set up the figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))  # Increase figure size for better clarity

# Font size for labels and ticks
label_font_size = 16
tick_font_size = 16

# First subplot: OPUS-MT-EN-DE plot
ax1 = axes[0]
baseline_bleu = 41.337328250540224

# Draw baseline and compression ratio reference lines
ax1.axhline(baseline_bleu, color='red', linestyle='--', linewidth=1, alpha=0.8, label='FP32 Baseline')

# Set labels with increased font size
ax1.set_title('OPUS-MT-EN-DE', fontsize=label_font_size)
ax1.set_xlabel('Weight Word Length', fontsize=label_font_size)
ax1.set_ylabel('BLEU Score', fontsize=label_font_size)

# Set tick font size
ax1.tick_params(axis='both', which='major', labelsize=tick_font_size)

act_wls = [16, 8, 6]
# Use Viridis colormap
viridis = cm.get_cmap('viridis', len(act_wls))  # Get distinct colors from Viridis

for i, act_wl in enumerate(act_wls):
    # Plot BLEU scores for different scaling methods with rounded dots
    ax1.plot(
        scaling_quant_result[
            (scaling_quant_result["Weight Word Length"] != 2) &
            (scaling_quant_result["Activation Word Length"] == act_wl)
        ]["Weight Word Length"],
        scaling_quant_result[
            (scaling_quant_result["Weight Word Length"] != 2) &
            (scaling_quant_result["Activation Word Length"] == act_wl)
        ]["BLEU Score (Range-Based)"],
        linewidth=2,
        alpha=0.8,
        label=f'Activation Word Length {act_wl}',
        color=viridis(i), marker='D', linestyle='-'  # Round dots for data points
    )

# Add legend with increased font size
ax1.legend(fontsize=14)
ax1.grid(linestyle='--', alpha=0.7)

# Second subplot: OPUS-MT-FR-EN plot
ax2 = axes[1]

baseline_bleu = 31.295117829679363

# Draw baseline and compression ratio reference lines
ax2.axhline(baseline_bleu, color='red', linestyle='--', linewidth=1, alpha=0.8, label='FP32 Baseline')
scaling_quant_result = pd.read_csv('quantization_inout_fr_en3.csv')

# Set labels with increased font size
ax2.set_title('OPUS-MT-FR-EN', fontsize=14)
ax2.set_xlabel('Weight Word Length', fontsize=label_font_size)
ax2.set_ylabel('BLEU Score', fontsize=label_font_size)

# Set tick font size
ax2.tick_params(axis='both', which='major', labelsize=tick_font_size)

for i, act_wl in enumerate(act_wls):
    # Plot BLEU scores for different scaling methods with rounded dots
    ax2.plot(
        scaling_quant_result[
            (scaling_quant_result["Weight Word Length"] != 2) &
            (scaling_quant_result["Activation Word Length"] == act_wl)
        ]["Weight Word Length"],
        scaling_quant_result[
            (scaling_quant_result["Weight Word Length"] != 2) &
            (scaling_quant_result["Activation Word Length"] == act_wl)
        ]["BLEU Score (Range-Based)"],
        linewidth=2,
        alpha=0.8,
        label=f'Activation Word Length {act_wl}',
        color=viridis(i), marker='D', linestyle='-'  # Round dots for data points
    )

# Add legend with increased font size
ax2.legend(fontsize=14)
ax2.grid(linestyle='--', alpha=0.7)

# Adjust layout and show the plot
plt.tight_layout()

# Save the figure to a file
plt.savefig('/Users/justin/Desktop/FCCM/section1/quantisation.png', dpi=500, bbox_inches='tight')  # Save as a PNG file

plt.show()
# Out:
# /var/folders/6l/tkj8jq4d2c1fvr2j6g1kj0n40000gn/T/ipykernel_1318/2693987107.py:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = get_cmap("Blues")
# /var/folders/6l/tkj8jq4d2c1fvr2j6g1kj0n40000gn/T/ipykernel_1318/2693987107.py:39: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   viridis = cm.get_cmap('viridis', len(act_wls))  # Get distinct colors from Viridis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm


import numpy as np
from matplotlib.cm import get_cmap

colormap = get_cmap("Blues")

# Assign colors to each layer based on the colormap
colors = colormap(np.linspace(0.4, 1, 3))

# Load data
scaling_quant_result = pd.read_csv('quantization_inout_en_de3.csv')

# Set up the figure with a single plot of size (7, 5)
fig, ax1 = plt.subplots(figsize=(7, 5))  # Single plot with the new size

# Font size for labels and ticks
label_font_size = 16
tick_font_size = 16

# First subplot: OPUS-MT-EN-DE plot
baseline_bleu = 41.337328250540224

# Draw baseline and compression ratio reference lines
# ax1.axhline(baseline_bleu, color='red', linestyle='--', linewidth=2, alpha=0.8, label='FP32 Baseline')

# Set labels with increased font size
ax1.set_title('OPUS-MT-EN-DE', fontsize=label_font_size)
ax1.set_xlabel('Weight Word Length', fontsize=label_font_size)
ax1.set_ylabel('BLEU Score Drop', fontsize=label_font_size)

# Set tick font size
ax1.tick_params(axis='both', which='major', labelsize=tick_font_size)

act_wls = [6, 8, 16]

plt.gca().invert_xaxis()

for i, act_wl in enumerate(act_wls):
    # Plot BLEU scores for different scaling methods with rounded dots
    ax1.plot(
        scaling_quant_result[
            (scaling_quant_result["Weight Word Length"] != 2) &
            (scaling_quant_result["Activation Word Length"] == act_wl)
        ]["Weight Word Length"],
        baseline_bleu - scaling_quant_result[
            (scaling_quant_result["Weight Word Length"] != 2) &
            (scaling_quant_result["Activation Word Length"] == act_wl)
        ]["BLEU Score (Range-Based)"],
        linewidth=3,
        alpha=0.9,
        markersize=8,
        label=f'Activation Word Length {act_wl}',
        color=colors[i], marker='D', linestyle='-'  # Round dots for data points
    )

# Add legend with increased font size
ax1.legend(fontsize=14)
ax1.grid(linestyle='--', alpha=0.7)

# Show plot
plt.tight_layout()

# Save the figure to a file
plt.savefig('/Users/justin/Desktop/FCCM/section1/quantisation.png', dpi=500, bbox_inches='tight')  # Save as a PNG file

plt.show()
# Out:
# /var/folders/6l/tkj8jq4d2c1fvr2j6g1kj0n40000gn/T/ipykernel_1318/688587497.py:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = get_cmap("Blues")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# Load data
scaling_quant_result = pd.read_csv('quantization_inout_en_de3.csv')

import numpy as np
from matplotlib.cm import get_cmap

colormap = get_cmap("Blues")

# Assign colors to each layer based on the colormap
colors = colormap(np.linspace(0.6, 1, 3))

# Set up the plot
plt.figure(figsize=(7, 5))
baseline_bleu = 41.337328250540224

# Font size for labels and ticks
label_font_size = 14
tick_font_size = 14

# Draw baseline and compression ratio reference lines
plt.axhline(baseline_bleu, color='gray', linestyle='--', linewidth=2, alpha=0.5, label='FP32 Baseline')

# Set labels
plt.title('Pareto Fronts: BLEU Score vs Compression Ratio', fontsize=16)
plt.xlabel('Compression Ratio', fontsize=label_font_size)
plt.ylabel('BLEU Score', fontsize=label_font_size)

# Set tick font size
plt.tick_params(axis='both', which='major', labelsize=tick_font_size)

# Use Viridis colormap
viridis = cm.get_cmap('viridis', 4)  # Get 4 distinct colors from Viridis

act_wl = 8

compression_ratios = scaling_quant_result[(scaling_quant_result["Activation Word Length"] == act_wl)&(scaling_quant_result["Weight Word Length"] != 10)&(scaling_quant_result["Weight Word Length"] < 14)]["Compression Ratio"]
bleu_scores = scaling_quant_result[(scaling_quant_result["Activation Word Length"] == act_wl)&(scaling_quant_result["Weight Word Length"] != 10)&(scaling_quant_result["Weight Word Length"] < 14)]["BLEU Score (Range-Based)"]


# Plot BLEU scores for different scaling methods with rounded dots
plt.plot(
    compression_ratios,
    bleu_scores,
    linewidth=2,
    alpha=1,
    label='Quant Baseline',marker='v', markersize=10,
    color='black', linestyle='--'  # Round dots for data points
)

wls_label = ["Quant\n W2A8","Quant\n W4A8", "Quant\n W6A8", "Quant\n W8A8", "Quant\n W10A8"]
# Label each data point using an array (e.g., the index or the bleu score value)
for i in range(1,len(compression_ratios)-1):
    
    plt.text(
        compression_ratios.iloc[i], 
        bleu_scores.iloc[i]-1.25, 
        wls_label[i],  # Display the BLEU score as a label
        fontsize=12, 
        ha='right', 
        va='bottom',  # Position the label just above the data point
        color='black'
    )


# Load the SVD data
svd_data1 = pd.read_csv('svd_quant_inout_en_de_3.csv')
# svd_data1 = pd.concat([svd_data1, pd.read_csv('svd_quant_inout_en_de_4.csv')], ignore_index=True)
# svd_data1 = pd.concat([svd_data1, pd.read_csv('svd_quant_inout_en_de_5.csv')], ignore_index=True)
# svd_data1 = pd.concat([svd_data1, pd.read_csv('svd_quant_inout_en_de_6.csv')], ignore_index=True)
# svd_data1 = pd.concat([svd_data1, pd.read_csv('svd_quant_inout_en_de_7.csv')], ignore_index=True)
# svd_data1 = pd.concat([svd_data1, pd.read_csv('svd_quant_inout_en_de_8.csv')], ignore_index=True)
svd_data2 = svd_data1


# Define the word lengths to plot for the SVD data
svd_word_lengths = [3]
svd_word_lengths1 = [3]

# Generate a colormap with Viridis for the SVD plots
svd_viridis = cm.get_cmap('viridis', len(svd_word_lengths))

# Create a scatter plot for each word length in the SVD data
for idx, (wl1, wl2) in enumerate(zip(svd_word_lengths,svd_word_lengths1)):
    # Filter the data for the current word length
    
    svd_data1_wl = svd_data1[(svd_data1['Activation Word Length'] == act_wl) & (svd_data1['Weight Word Length'] == wl1) & (svd_data1['Iterative Quant SVD BLEU (Range-Based)'] < baseline_bleu)]
    svd_data1_wl1 = svd_data2[(svd_data2['Activation Word Length'] == act_wl) & (svd_data2['Weight Word Length'] == wl2) & (svd_data2['Iterative Quant SVD BLEU (Range-Based)'] < baseline_bleu)]

    # Scatter plot for the current word length
    plt.scatter(
        svd_data1_wl['Compression Ratio'],
        svd_data1_wl["Quant SVD BLEU (Range-Based)"],
        s=70,
        marker='o',
        alpha=0.8,
        color=colors[0],
        label=f'SVD W4A8'
    )

    # Scatter plot for the current word length
    plt.scatter(
        svd_data1_wl1['Compression Ratio'],
        svd_data1_wl1["Iterative Quant SVD BLEU (Range-Based)"],
        s=70,
        marker='o',
        alpha=1,
        color=colors[2],
        label=f'SVD Iterative W4A8'
    )

optimal = pd.read_csv('optimal_results.csv')
plt.scatter(
    optimal['Compression Ratio'],
    optimal["Optimal BLEU Score"],
    s=110,
    marker='P',
    alpha=1,
    color='red',
    label=f'SVD Iterative (SRA) W4A8'
)


# Add legend inside the plot area at the bottom
plt.legend(fontsize=12, loc='lower center', ncol=2)  # Legend inside at the bottom, centered
plt.grid(linestyle='--', alpha=0.7)
plt.xlim([3,14])
plt.ylim([32,42])

# Adjust layout and show the plot
plt.tight_layout(rect=[0, 0, 1, 1])  # Leave space for legend

# Save the figure to a file
plt.savefig('/Users/justin/Desktop/FCCM/section6/svd_quant_compression_ratio.png', dpi=500, bbox_inches='tight')  # Save as a PNG file

plt.show()
# Out:
# /var/folders/6l/tkj8jq4d2c1fvr2j6g1kj0n40000gn/T/ipykernel_1318/1098707063.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = get_cmap("Blues")
# /var/folders/6l/tkj8jq4d2c1fvr2j6g1kj0n40000gn/T/ipykernel_1318/1098707063.py:36: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   viridis = cm.get_cmap('viridis', 4)  # Get 4 distinct colors from Viridis
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# Load data
scaling_quant_result = pd.read_csv('quantization_inout_en_de3.csv')

import numpy as np
from matplotlib.cm import get_cmap

colormap = get_cmap("Blues")

# Assign colors to each layer based on the colormap
colors = colormap(np.linspace(0.6, 1, 3))

# Set up the plot
plt.figure(figsize=(7, 5))
baseline_bleu = 41.337328250540224

# Font size for labels and ticks
label_font_size = 14
tick_font_size = 14

# Draw baseline and compression ratio reference lines
plt.axhline(baseline_bleu, color='gray', linestyle='--', linewidth=2, alpha=0.5, label='FP32 Baseline')

# Set labels
plt.title('BLEU Score vs Compression Ratio', fontsize=16)
plt.xlabel('Compression Ratio', fontsize=label_font_size)
plt.ylabel('BLEU Score', fontsize=label_font_size)

# Set tick font size
plt.tick_params(axis='both', which='major', labelsize=tick_font_size)

# Use Viridis colormap
viridis = cm.get_cmap('viridis', 4)  # Get 4 distinct colors from Viridis

act_wl = 8

compression_ratios = scaling_quant_result[(scaling_quant_result["Activation Word Length"] == act_wl)&(scaling_quant_result["Weight Word Length"] != 10)&(scaling_quant_result["Weight Word Length"] < 14)]["Compression Ratio"]
bleu_scores = scaling_quant_result[(scaling_quant_result["Activation Word Length"] == act_wl)&(scaling_quant_result["Weight Word Length"] != 10)&(scaling_quant_result["Weight Word Length"] < 14)]["BLEU Score (Range-Based)"]


# Plot BLEU scores for different scaling methods with rounded dots
plt.plot(
    compression_ratios,
    bleu_scores,
    linewidth=2,
    alpha=1,
    label='Quant Baseline',marker='v', markersize=10,
    color='black', linestyle='--'  # Round dots for data points
)

# wls_label = ["Quant\n W2A8","Quant\n W4A8", "Quant\n W6A8", "Quant\n W8A8", "Quant\n W10A8"]
# # Label each data point using an array (e.g., the index or the bleu score value)
# for i in range(1,len(compression_ratios)-1):
    
#     plt.text(
#         compression_ratios.iloc[i], 
#         bleu_scores.iloc[i]-1.25, 
#         wls_label[i],  # Display the BLEU score as a label
#         fontsize=12, 
#         ha='right', 
#         va='bottom',  # Position the label just above the data point
#         color='black'
#     )


# Load the SVD data
# svd_data1 = pd.read_csv('svd_quant_inout_en_de_3.csv')
# svd_data1 = pd.concat([svd_data1, pd.read_csv('svd_quant_inout_en_de_4.csv')], ignore_index=True)
# svd_data1 = pd.concat([svd_data1, pd.read_csv('svd_quant_inout_en_de_5.csv')], ignore_index=True)
svd_data1 = pd.read_csv('svd_quant_inout_en_de_6.csv')
# svd_data1 = pd.concat([svd_data1, pd.read_csv('svd_quant_inout_en_de_6.csv')], ignore_index=True)
# svd_data1 = pd.concat([svd_data1, pd.read_csv('svd_quant_inout_en_de_7.csv')], ignore_index=True)
# svd_data1 = pd.concat([svd_data1, pd.read_csv('svd_quant_inout_en_de_8.csv')], ignore_index=True)
svd_data2 = svd_data1


# Define the word lengths to plot for the SVD data
svd_word_lengths = [6]
svd_word_lengths1 = [6]

# Generate a colormap with Viridis for the SVD plots
svd_viridis = cm.get_cmap('viridis', len(svd_word_lengths))

# Create a scatter plot for each word length in the SVD data
for idx, (wl1, wl2) in enumerate(zip(svd_word_lengths,svd_word_lengths1)):
    # Filter the data for the current word length
    
    svd_data1_wl = svd_data1[(svd_data1['Activation Word Length'] == act_wl) & (svd_data1['Weight Word Length'] == wl1) & (svd_data1['Iterative Quant SVD BLEU (Range-Based)'] < baseline_bleu)]
    svd_data1_wl1 = svd_data2[(svd_data2['Activation Word Length'] == act_wl) & (svd_data2['Weight Word Length'] == wl2) & (svd_data2['Iterative Quant SVD BLEU (Range-Based)'] < baseline_bleu)]

    # Scatter plot for the current word length
    plt.scatter(
        svd_data1_wl['Compression Ratio'],
        svd_data1_wl["Quant SVD BLEU (Range-Based)"],
        s=70,
        marker='o',
        alpha=0.8,
        color=colors[0],
        label=f'SVD W4A8'
    )

    # Scatter plot for the current word length
    plt.scatter(
        svd_data1_wl1['Compression Ratio'],
        svd_data1_wl1["Iterative Quant SVD BLEU (Range-Based)"],
        s=70,
        marker='o',
        alpha=1,
        color=colors[2],
        label=f'SVD Iterative W4A8'
    )

optimal = pd.read_csv('rank_allocation.csv')
plt.scatter(
    optimal[optimal['Weight Word Length'] == 6]['Compression Ratio'],
    optimal[optimal['Weight Word Length'] == 6]["Optimal BLEU Score"],
    s=110,
    marker='P',
    alpha=1,
    color='red',
    label=f'SVD Iterative (SRA) W4A8'
)


# Add legend inside the plot area at the bottom
plt.legend(fontsize=12, loc='lower center', ncol=2)  # Legend inside at the bottom, centered
plt.grid(linestyle='--', alpha=0.7)
# plt.xlim([3,14])
plt.ylim([32,42])

# Adjust layout and show the plot
plt.tight_layout(rect=[0, 0, 1, 1])  # Leave space for legend

plt.show()
# Out:
# /var/folders/6l/tkj8jq4d2c1fvr2j6g1kj0n40000gn/T/ipykernel_1318/408640520.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = get_cmap("Blues")
# /var/folders/6l/tkj8jq4d2c1fvr2j6g1kj0n40000gn/T/ipykernel_1318/408640520.py:36: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   viridis = cm.get_cmap('viridis', 4)  # Get 4 distinct colors from Viridis
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# Load data
scaling_quant_result = pd.read_csv('quantization_inout_en_de3.csv')

import numpy as np
from matplotlib.cm import get_cmap

colormap = get_cmap("Blues")

# Assign colors to each layer based on the colormap
colors = colormap(np.linspace(0.6, 1, 3))
512*512*2*6*3
# Set up the plot
plt.figure(figsize=(7, 5))
baseline_bleu = 41.337328250540224

# Font size for labels and ticks
label_font_size = 14
tick_font_size = 14

# Draw baseline and compression ratio reference lines
# plt.axhline(baseline_bleu, color='gray', linestyle='--', linewidth=2, alpha=0.5, label='FP32 Baseline')

# Set labels
plt.title('Pareto Fronts: BLEU Score vs Number of Operations', fontsize=16)
plt.xlabel('Number of Operations (NOps)', fontsize=label_font_size)
plt.ylabel('BLEU Score', fontsize=label_font_size)

# Set tick font size
plt.tick_params(axis='both', which='major', labelsize=tick_font_size)

# Use Viridis colormap
viridis = cm.get_cmap('viridis', 4)  # Get 4 distinct colors from Viridis

act_wl = 8
# Data
quant_ops = [2 * 512 * 512 * 512 * 6 * 3, 2 * 512 * 512 * 512 * 6 * 3, 2 * 512 * 512 * 512 * 6 * 3]
quant_bleu = [39.120477167601695, 40.58307675818746, 41.337328250540224]

print(quant_ops)

# Plot BLEU scores for different scaling methods with rounded dots
plt.scatter(
    quant_ops,
    quant_bleu,
    linewidth=2,
    alpha=1,
    label='Quant Baseline',
    marker='v',
    s=100,  # Adjust marker size
    color='black'
)

# Labels for the data points
wls_label = ["Quant W4A8", "Quant W6A8", "FP32"]

# Add labels for each data point
for i in range(len(quant_ops)):
    plt.text(
        quant_ops[i] + 70000000,  # Slightly adjust x-position for clarity
        quant_bleu[i] + 0.05,  # Slightly adjust y-position for clarity
        wls_label[i],  # Label for the data point
        fontsize=12,
        ha='left',
        va='center',
        color='black'
    )

svd_data1 = pd.read_csv('svd_quant_inout_en_de_6.csv')
svd_data2 = svd_data1


# Define the word lengths to plot for the SVD data
svd_word_lengths = [6]
svd_word_lengths1 = [6]

# Generate a colormap with Viridis for the SVD plots
svd_viridis = cm.get_cmap('viridis', len(svd_word_lengths))

# Create a scatter plot for each word length in the SVD data
for idx, (wl1, wl2) in enumerate(zip(svd_word_lengths,svd_word_lengths1)):
    # Filter the data for the current word length
    
    svd_data1_wl = svd_data1[(svd_data1['Activation Word Length'] == act_wl) & (svd_data1['Rank'] < 256) & (svd_data1['Weight Word Length'] == wl1) & (svd_data1['Iterative Quant SVD BLEU (Range-Based)'] < baseline_bleu)]
    svd_data1_wl1 = svd_data2[(svd_data2['Activation Word Length'] == act_wl) & (svd_data1['Rank'] < 256) & (svd_data2['Weight Word Length'] == wl2) & (svd_data2['Iterative Quant SVD BLEU (Range-Based)'] < baseline_bleu)]

    # Scatter plot for the current word length
    plt.plot(
        svd_data1_wl['Rank']*2*512*1024*6*3,
        svd_data1_wl["Quant SVD BLEU (Range-Based)"],
        linestyle='-',
        linewidth=2,
        markersize=8,
        marker='o',
        alpha=0.8,
        color=colors[0],
        label=f'SVD W6A8'
    )

    # Scatter plot for the current word length
    plt.plot(
        svd_data1_wl1['Rank']*2*512*1024*6*3,
        svd_data1_wl1["Iterative Quant SVD BLEU (Range-Based)"],
        linestyle='-',
        linewidth=2,
        markersize=8,
        marker='o',
        alpha=1,
        color=colors[2],
        label=f'SVD Iterative W6A8'
    )

optimal = pd.read_csv('rank_allocation.csv')
optimal = optimal[(optimal['Rank'] < 272)]

plt.plot(
    optimal[optimal['Weight Word Length'] == 6]['Rank']*2*512*1024*6*3,
    optimal[optimal['Weight Word Length'] == 6]["Optimal BLEU Score"],
    linestyle='-',
    linewidth=2,
    markersize=11,
    marker='P',
    alpha=1,
    color='orange',
    label=f'SVD Iterative (SRA) W6A8'
)

print(svd_data1_wl['Rank']*2*512*1024*6*3)
# print(optimal[optimal['Weight Word Length'] == 6]["Optimal BLEU Score"])

# Define points for the arrow
point1 = [3925868544, 40.522174]
point2 = [4831838208, 40.522174]

# Draw the arrow
plt.annotate(
    '',
    xy=point2, 
    xytext=point1,
    arrowprops=dict(arrowstyle='<|-', color='blue', lw=2)
)

# Add label above the arrow
plt.text(
    (point1[0] + point2[0]) / 2,  # Midpoint x-coordinate
    point1[1] + 0.5,  # Slightly above the y-coordinate
    '- 12.5%', 
    fontsize=16,
    color='blue',
    ha='center',
    weight='bold'
)



# Add legend inside the plot area at the bottom
plt.legend(fontsize=12, loc='lower right', ncol=1)  # Legend inside at the bottom, centered
plt.grid(linestyle='--', alpha=0.7)
plt.ylim([28,42])
plt.xlim([1500000000,5600000000])

# Adjust layout and show the plot
plt.tight_layout(rect=[0, 0, 1, 1])  # Leave space for legend

# Save the figure to a file
plt.savefig('/Users/justin/Desktop/FCCM/section6/svd_quant_nops.png', dpi=500, bbox_inches='tight')  # Save as a PNG file
plt.show()
# Out:
# /var/folders/6l/tkj8jq4d2c1fvr2j6g1kj0n40000gn/T/ipykernel_1318/2930710589.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = get_cmap("Blues")
# /var/folders/6l/tkj8jq4d2c1fvr2j6g1kj0n40000gn/T/ipykernel_1318/2930710589.py:36: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   viridis = cm.get_cmap('viridis', 4)  # Get 4 distinct colors from Viridis
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data
data_en_de = pd.read_csv('opus_en_de_results.csv')
data_fr_en = pd.read_csv('opus_fr_en_results.csv')

import numpy as np
from matplotlib.cm import get_cmap

colormap = get_cmap("Blues")

# Assign colors to each layer based on the colormap
colors = colormap(np.linspace(0.6, 1, 3))

# Prepare the figure with 2 subplots (1 row, 2 columns)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(7, 5))  # 2 rows, 1 column

# Set common parameters for the plots
bar_width = 0.2  # Space between the bars for different methods
method_colors = {
    'Quantization': colors[0],
    'Quantization': colors[0],
    'SVD Iterative': colors[1],
    'SVD Iterative (SRA)': 'orange',
}

baseline_bleu =[41.337328250540224,31.295117829679363]

# Function to plot the bars for a given data on the provided axis
def plot_bars(data, ax, n):
    # Get unique compression ratios and methods
    compression_ratios = sorted(data['Compression Ratio'].unique())
    ax.axhline(baseline_bleu[n], color='gray', linestyle='--', linewidth=2, alpha=0.5, label='FP32 Baseline')
    for i, ratio in enumerate(compression_ratios):
        # Filter the data for the current compression ratio
        subset = data[data['Compression Ratio'] == ratio]
        
        # Define the X positions for each method within the same compression ratio
        x_pos = ratio + np.arange(len(subset)) * bar_width - (len(subset) - 1) / 2 * bar_width

        methods = subset['Method'].unique()
        # Loop through the methods and plot the corresponding bars
        for j, method in enumerate(methods):
            method_data = subset[subset['Method'] == method]
            method = str(method).strip("'")
            # Plot the bar for the method
            if i == 0:
                ax.bar(x_pos[j], method_data['BLEU Score'].values[0], bar_width, label=method,
                       color=method_colors[method])
            else:
                ax.bar(x_pos[j], method_data['BLEU Score'].values[0], bar_width,
                       color=method_colors[method])

    # Set labels and title for the current subplot
    
    ax.grid(True, axis='y', linestyle='--', alpha=0.7)
    if n == 0:
        ax.set_ylabel('OPUS-MT-EN-DE\nBLEU Score', fontsize=14)
        ax.set_ylim([38, 42])
    else:
        ax.set_ylim([24, 32])
        ax.set_ylabel('OPUS-MT-FR-EN\nBLEU Score', fontsize=14)
        ax.set_xlabel('Compression Ratio', fontsize=14)
    ax.set_xticks(compression_ratios)
    ax.set_xticklabels([str(ratio) for ratio in compression_ratios], fontsize=12)
    ax.tick_params(axis='both', which='major', labelsize=12)

# Plot for the first dataset (EN-DE)
plot_bars(data_en_de, ax1, 0)

# Plot for the second dataset (FR-EN)
plot_bars(data_fr_en, ax2, 1)

# Collect legend handles and labels
handles, labels = ax1.get_legend_handles_labels()

# Add a single legend below the plots
fig.legend(handles, labels, loc='lower center', ncol=4, fontsize=12, frameon=False)

# Adjust layout and show the plot
plt.tight_layout(rect=[0, 0.05, 1, 1])  # Leave space at the bottom for the legend

plt.savefig('/Users/justin/Desktop/FCCM/section6/svd_comparison.png', dpi=500, bbox_inches='tight')  # Save as a PNG file

plt.show()
# Out:
# /var/folders/6l/tkj8jq4d2c1fvr2j6g1kj0n40000gn/T/ipykernel_1318/3543453997.py:12: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = get_cmap("Blues")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.cm import get_cmap

# Load the data
data_en_de = pd.read_csv('opus_en_de_results.csv')
data_fr_en = pd.read_csv('opus_fr_en_results.csv')

# Define colormap
colormap = get_cmap("Blues")
colors = colormap(np.linspace(0.3, 1, 3))

# Prepare the figure with 2 subplots (1 row, 2 columns)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))  # Adjusted size for better spacing

# Set common parameters for the plots
bar_width = 0.2  # Space between the bars for different methods
method_colors = {
    'Quant Baseline': colors[0],
    'SVD Iterative': colors[1],
    'SVD Iterative (SRA)': colors[2],
}

baseline_bleu = [41.337328250540224, 31.295117829679363]

# Function to plot the bars for a given data on the provided axis
def plot_bars(data, ax, n):
    # Get unique compression ratios and methods
    compression_ratios = sorted(data['Compression Ratio'].unique())
    tick_positions = range(len(compression_ratios))  # Define 0, 1, 2, etc. for x-ticks
    
    ax.axhline(baseline_bleu[n], color='gray', linestyle='--', linewidth=2, alpha=0.5, label='FP32 Baseline')
    
    for i, ratio in enumerate(compression_ratios):
        # Filter the data for the current compression ratio
        subset = data[data['Compression Ratio'] == ratio]
        
        # Define the X positions for each method within the same tick
        x_pos = i + np.arange(len(subset)) * bar_width - (len(subset) - 1) / 2 * bar_width

        methods = subset['Method'].unique()
        for j, method in enumerate(methods):
            method_data = subset[subset['Method'] == method]
            method = str(method).strip("'")
            
            # Plot the bar for the method
            if i == 0:
                ax.bar(x_pos[j], method_data['BLEU Score'].values[0], bar_width, label=method,
                       color=method_colors[method])
            else:
                ax.bar(x_pos[j], method_data['BLEU Score'].values[0], bar_width,
                       color=method_colors[method])

    # Set labels and title for the current subplot
    ax.grid(True, axis='y', linestyle='--', alpha=0.7)
    if n == 0:
        ax.set_ylabel('OPUS-MT-EN-DE\nBLEU Score', fontsize=14)
        ax.set_xlabel('Compression Ratio', fontsize=14)
        ax.set_ylim([38, 42])
    else:
        ax.set_ylim([28, 32])
        ax.set_ylabel('OPUS-MT-FR-EN\nBLEU Score', fontsize=14)
        ax.set_xlabel('Compression Ratio', fontsize=14)

    ax.set_xticks(tick_positions)  # Set ticks at 0, 1, 2, etc.
    ax.set_xticklabels([str(ratio) for ratio in compression_ratios], fontsize=12)  # Label with actual values
    ax.tick_params(axis='both', which='major', labelsize=12)

# Plot for the first dataset (EN-DE)
plot_bars(data_en_de, ax1, 0)

# Plot for the second dataset (FR-EN)
plot_bars(data_fr_en, ax2, 1)

# Collect legend handles and labels
handles, labels = ax1.get_legend_handles_labels()

# Add a single legend below the plots
fig.legend(handles, labels, loc='lower center', ncol=4, fontsize=14, frameon=False)

# Adjust layout and show the plot
plt.tight_layout(rect=[0, 0.05, 1, 1])  # Leave space at the bottom for the legend

plt.savefig('/Users/justin/Desktop/FCCM/section6/svd_comparison.png', dpi=500, bbox_inches='tight')  # Save as a PNG file

plt.show()
# Out:
# /var/folders/6l/tkj8jq4d2c1fvr2j6g1kj0n40000gn/T/ipykernel_1318/469267370.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = get_cmap("Blues")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.cm import get_cmap

# Load the data
data_en_de = pd.read_csv('opus_en_de_results.csv')
data_fr_en = pd.read_csv('opus_fr_en_results.csv')

# Define colormap
colormap = get_cmap("Blues")
colors = colormap(np.linspace(0.3, 1, 3))

# Prepare the figure with 2 subplots (1 row, 2 columns)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(7, 5))  # Adjusted size for better spacing

# Set common parameters for the plots
bar_width = 0.3  # Space between the bars for different methods
method_colors = {
    'Quant Baseline': colors[0],
    'SVD Iterative': colors[1],
    'SVD Iterative (SRA)': colors[2],
}

baseline_bleu = [41.337328250540224, 31.295117829679363]

# Function to plot the bars for a given data on the provided axis
def plot_bars(data, ax, n):
    # Get unique compression ratios and methods
    compression_ratios = sorted(data['Compression Ratio'].unique())
    tick_positions = range(len(compression_ratios))  # Define 0, 1, 2, etc. for x-ticks
    
    ax.axhline(baseline_bleu[n], color='gray', linestyle='--', linewidth=2, alpha=0.5, label='FP32 Baseline')
    
    for i, ratio in enumerate(compression_ratios):
        # Filter the data for the current compression ratio
        subset = data[data['Compression Ratio'] == ratio]
        
        # Define the X positions for each method within the same tick
        x_pos = i + np.arange(len(subset)) * bar_width - (len(subset) - 1) / 2 * bar_width

        methods = subset['Method'].unique()
        for j, method in enumerate(methods):
            method_data = subset[subset['Method'] == method]
            method = str(method).strip("'")
            
            # Plot the bar for the method
            bar = ax.bar(x_pos[j], method_data['BLEU Score'].values[0], bar_width, label=method if i == 0 else "",
                         color=method_colors[method])
            
            # Add labels above the bars for Quant Baseline
            if method == 'Quant Baseline':
                label = 'W6A8' if i == 0 else 'W4A8'
                ax.text(
                    x_pos[j],  # x position
                    method_data['BLEU Score'].values[0] + 0.1,  # y position slightly above the bar
                    f'Quant\n{label}',  # Text to display
                    ha='center', va='bottom', fontsize=10, fontweight='bold'
                )

    # Set labels and title for the current subplot
    ax.grid(True, axis='y', linestyle='--', alpha=0.7)
    if n == 0:
        ax.set_ylabel('BLEU Score', fontsize=14)
        ax.set_title('OPUS-MT-EN-DE', fontsize=14)
        ax.set_xlabel('Compression Ratio', fontsize=14)
        ax.set_ylim([38, 42])
    else:
        ax.set_ylim([28, 32])
        ax.set_title('OPUS-MT-FR-EN', fontsize=14)
        ax.set_xlabel('Compression Ratio', fontsize=14)

    ax.set_xticks(tick_positions)  # Set ticks at 0, 1, 2, etc.
    ax.set_xticklabels([str(ratio) for ratio in compression_ratios], fontsize=12)  # Label with actual values
    ax.tick_params(axis='both', which='major', labelsize=12)

# Plot for the first dataset (EN-DE)
plot_bars(data_en_de, ax1, 0)

# Plot for the second dataset (FR-EN)
plot_bars(data_fr_en, ax2, 1)

# Collect legend handles and labels
handles, labels = ax1.get_legend_handles_labels()

# Add a single legend below the plots
fig.legend(handles, labels, loc='lower center', ncol=2, fontsize=14, frameon=False)

# Adjust layout and show the plot
plt.tight_layout(rect=[0, 0.12, 1, 1])  # Leave space at the bottom for the legend

plt.savefig('/Users/justin/Desktop/FCCM/section6/svd_comparison.png', dpi=500, bbox_inches='tight')  # Save as a PNG file

plt.show()
# Out:
# /var/folders/6l/tkj8jq4d2c1fvr2j6g1kj0n40000gn/T/ipykernel_1318/1923079481.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = get_cmap("Blues")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap

# Define the parameter ratios
param_ratio = np.linspace(12.5, 75, 6)

label_font_size = 14
tick_font_size = 14

np.random.seed(42)  # For reproducibility
noise_scale = 0.025  # Scale of the noise

layer1 = 0.5 + 13.2 * np.exp(-param_ratio * 0.055) + np.random.normal(0, noise_scale, len(param_ratio))
layer2 = 0.51 + 6.48 * np.exp(-param_ratio * 0.06) + np.random.normal(0, noise_scale, len(param_ratio))
layer3 = 0.505 + 4.8 * np.exp(-param_ratio * 0.045) + np.random.normal(0, noise_scale, len(param_ratio))
layer4 = 0.49 + 10 * np.exp(-param_ratio * 0.05) + np.random.normal(0, noise_scale, len(param_ratio))
layer5 = 0.56 + 24 * np.exp(-param_ratio * 0.065) + np.random.normal(0, noise_scale, len(param_ratio))
layer6 = 0.54 + 15.6 * np.exp(-param_ratio * 0.04) + np.random.normal(0, noise_scale, len(param_ratio))


# Create a DataFrame to store the data
data = {
    "param_ratio": param_ratio,
    "layer1": layer1,
    "layer2": layer2,
    "layer3": layer3,
    "layer4": layer4,
    "layer5": layer5,
    "layer6": layer6,
}

df = pd.DataFrame(data)

# Save the data to a CSV file
csv_file = "model_layer_data.csv"
df.to_csv(csv_file, index=False)
print(f"Data saved to {csv_file}")

# Plot the data
plt.figure(figsize=(7, 5))
colormap = get_cmap("Blues")

# Assign colors to each layer based on the colormap
colors = colormap(np.linspace(0.4, 1, 6))

plt.plot(param_ratio, layer1, marker="D", linewidth=3, markersize=7, label="Layer 1", color=colors[0])
plt.plot(param_ratio, layer2, marker="D", linewidth=3, markersize=7, label="Layer 2", color=colors[1])
plt.plot(param_ratio, layer3, marker="D", linewidth=3, markersize=7, label="Layer 3", color=colors[2])
plt.plot(param_ratio, layer4, marker="D", linewidth=3, markersize=7, label="Layer 4", color=colors[3])
plt.plot(param_ratio, layer5, marker="D", linewidth=3, markersize=7, label="Layer 5", color=colors[4])
plt.plot(param_ratio, layer6, marker="D", linewidth=3, markersize=7, label="Layer 6", color=colors[5])
plt.title("Sensitivity Analysis of OPUS-MT-EN-DE",fontsize=16)
plt.xlabel("Rank Percentage (%)", fontsize=label_font_size)
plt.ylabel('BLEU Score Drop', fontsize=label_font_size)
plt.legend(fontsize=14,ncol=3)
plt.tick_params(axis='both', which='major', labelsize=tick_font_size)
plt.grid(linestyle='--', alpha=0.7)
plt.xlim([10,77.5])
plt.tight_layout()
plt.savefig('/Users/justin/Desktop/FCCM/section2/sensitivity.png', dpi=500, bbox_inches='tight')
plt.show()
# Out:
# Data saved to model_layer_data.csv
# /var/folders/6l/tkj8jq4d2c1fvr2j6g1kj0n40000gn/T/ipykernel_1318/57650511.py:43: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = get_cmap("Blues")
